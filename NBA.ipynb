# %% [markdown]
# # NBA EXPLORATORY DATA ANALYSIS

# %% [markdown]
# # First we will import the proper packeges, modules and load our data set

# %%
import pandas as pd
import csv as csv
NBA = pd.read_csv('NBA.csv', index_col=0)

# %%
NBA
# Out:
#              player_name team_abbreviation   age  player_height  \
# 0          Dennis Rodman               CHI  36.0         198.12
# 1      Dwayne Schintzius               LAC  28.0         215.90
# 2           Earl Cureton               TOR  39.0         205.74
# 3            Ed O'Bannon               DAL  24.0         203.20
# 4            Ed Pinckney               MIA  34.0         205.74
# ...                  ...               ...   ...            ...
# 12300    Markieff Morris               MIA  32.0         205.74
# 12301     Markelle Fultz               ORL  24.0         193.04
# 12302       Marcus Smart               BOS  28.0         193.04
# 12303     Marcus Garrett               MIA  23.0         195.58
# 12304       Micah Potter               DET  24.0         208.28
#
#        player_weight                      college country draft_year  \
# 0          99.790240  Southeastern Oklahoma State     USA       1986
# 1         117.933920                      Florida     USA       1990
# 2          95.254320                Detroit Mercy     USA       1979
# 3         100.697424                         UCLA     USA       1995
# 4         108.862080                    Villanova     USA       1985
# ...              ...                          ...     ...        ...
# 12300     111.130040                       Kansas     USA       2011
# 12301      94.800728                   Washington     USA       2017
# 12302      99.790240               Oklahoma State     USA       2014
# 12303      92.986360                       Kansas     USA  Undrafted
# 12304     112.490816                    Wisconsin     USA  Undrafted
#
#       draft_round draft_number  ...   pts   reb  ast  net_rating  oreb_pct  \
# 0               2           27  ...   5.7  16.1  3.1        16.1     0.186
# 1               1           24  ...   2.3   1.5  0.3        12.3     0.078
# 2               3           58  ...   0.8   1.0  0.4        -2.1     0.105
# 3               1            9  ...   3.7   2.3  0.6        -8.7     0.060
# 4               1           10  ...   2.4   2.4  0.2       -11.2     0.109
# ...           ...          ...  ...   ...   ...  ...         ...       ...
# 12300           1           13  ...   7.6   2.6  1.4         4.5     0.059
# 12301           1            1  ...  10.8   2.7  5.5        -5.3     0.010
# 12302           1            6  ...  12.1   3.8  5.9         9.3     0.018
# 12303   Undrafted    Undrafted  ...   1.1   1.9  0.6         5.8     0.072
# 12304   Undrafted    Undrafted  ...   4.0   3.0  0.0       -56.4     0.095
#
#        dreb_pct  usg_pct  ts_pct  ast_pct   season
# 0         0.323    0.100   0.479    0.113  1996-97
# 1         0.151    0.175   0.430    0.048  1996-97
# 2         0.102    0.103   0.376    0.148  1996-97
# 3         0.149    0.167   0.399    0.077  1996-97
# 4         0.179    0.127   0.611    0.040  1996-97
# ...         ...      ...     ...      ...      ...
# 12300     0.089    0.197   0.547    0.116  2021-22
# 12301     0.116    0.265   0.517    0.448  2021-22
# 12302     0.093    0.179   0.540    0.245  2021-22
# 12303     0.108    0.086   0.280    0.069  2021-22
# 12304     0.125    0.148   0.505    0.000  2021-22
#
# [12305 rows x 21 columns]

# %% [markdown]
# # Display first and last 5 rows

# %%
NBA.head(5)
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12      99.790240
# 1  Dwayne Schintzius               LAC  28.0         215.90     117.933920
# 2       Earl Cureton               TOR  39.0         205.74      95.254320
# 3        Ed O'Bannon               DAL  24.0         203.20     100.697424
# 4        Ed Pinckney               MIA  34.0         205.74     108.862080
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1                      Florida     USA       1990           1           24
# 2                Detroit Mercy     USA       1979           3           58
# 3                         UCLA     USA       1995           1            9
# 4                    Villanova     USA       1985           1           10
#
#    ...  pts   reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  \
# 0  ...  5.7  16.1  3.1        16.1     0.186     0.323    0.100   0.479
# 1  ...  2.3   1.5  0.3        12.3     0.078     0.151    0.175   0.430
# 2  ...  0.8   1.0  0.4        -2.1     0.105     0.102    0.103   0.376
# 3  ...  3.7   2.3  0.6        -8.7     0.060     0.149    0.167   0.399
# 4  ...  2.4   2.4  0.2       -11.2     0.109     0.179    0.127   0.611
#
#    ast_pct   season
# 0    0.113  1996-97
# 1    0.048  1996-97
# 2    0.148  1996-97
# 3    0.077  1996-97
# 4    0.040  1996-97
#
# [5 rows x 21 columns]

# %%
NBA.tail(5)
# Out:
#            player_name team_abbreviation   age  player_height  player_weight  \
# 12300  Markieff Morris               MIA  32.0         205.74     111.130040
# 12301   Markelle Fultz               ORL  24.0         193.04      94.800728
# 12302     Marcus Smart               BOS  28.0         193.04      99.790240
# 12303   Marcus Garrett               MIA  23.0         195.58      92.986360
# 12304     Micah Potter               DET  24.0         208.28     112.490816
#
#               college country draft_year draft_round draft_number  ...   pts  \
# 12300          Kansas     USA       2011           1           13  ...   7.6
# 12301      Washington     USA       2017           1            1  ...  10.8
# 12302  Oklahoma State     USA       2014           1            6  ...  12.1
# 12303          Kansas     USA  Undrafted   Undrafted    Undrafted  ...   1.1
# 12304       Wisconsin     USA  Undrafted   Undrafted    Undrafted  ...   4.0
#
#        reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct  \
# 12300  2.6  1.4         4.5     0.059     0.089    0.197   0.547    0.116
# 12301  2.7  5.5        -5.3     0.010     0.116    0.265   0.517    0.448
# 12302  3.8  5.9         9.3     0.018     0.093    0.179   0.540    0.245
# 12303  1.9  0.6         5.8     0.072     0.108    0.086   0.280    0.069
# 12304  3.0  0.0       -56.4     0.095     0.125    0.148   0.505    0.000
#
#         season
# 12300  2021-22
# 12301  2021-22
# 12302  2021-22
# 12303  2021-22
# 12304  2021-22
#
# [5 rows x 21 columns]

# %% [markdown]
# # What are the columns names?

# %%
NBA.columns
# Out:
# Index(['player_name', 'team_abbreviation', 'age', 'player_height',
#        'player_weight', 'college', 'country', 'draft_year', 'draft_round',
#        'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating', 'oreb_pct',
#        'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season'],
#       dtype='object')

# %% [markdown]
# # Lets rename a couple columns

# %%
NBA = NBA.rename(columns={'player_weight': 'weight', 'player_height': 'height'})

print(NBA.columns)
# Out:
# Index(['player_name', 'team_abbreviation', 'age', 'height', 'weight',
#        'college', 'country', 'draft_year', 'draft_round', 'draft_number', 'gp',
#        'pts', 'reb', 'ast', 'net_rating', 'oreb_pct', 'dreb_pct', 'usg_pct',
#        'ts_pct', 'ast_pct', 'season'],
#       dtype='object')

# %% [markdown]
# # Remove duplicates from dataset

# %%
NBA = NBA.drop_duplicates()
NBA # No duplicates found ,has same amount of row and columns
# Out:
#              player_name team_abbreviation   age  height      weight  \
# 0          Dennis Rodman               CHI  36.0  198.12   99.790240
# 1      Dwayne Schintzius               LAC  28.0  215.90  117.933920
# 2           Earl Cureton               TOR  39.0  205.74   95.254320
# 3            Ed O'Bannon               DAL  24.0  203.20  100.697424
# 4            Ed Pinckney               MIA  34.0  205.74  108.862080
# ...                  ...               ...   ...     ...         ...
# 12300    Markieff Morris               MIA  32.0  205.74  111.130040
# 12301     Markelle Fultz               ORL  24.0  193.04   94.800728
# 12302       Marcus Smart               BOS  28.0  193.04   99.790240
# 12303     Marcus Garrett               MIA  23.0  195.58   92.986360
# 12304       Micah Potter               DET  24.0  208.28  112.490816
#
#                            college country draft_year draft_round  \
# 0      Southeastern Oklahoma State     USA       1986           2
# 1                          Florida     USA       1990           1
# 2                    Detroit Mercy     USA       1979           3
# 3                             UCLA     USA       1995           1
# 4                        Villanova     USA       1985           1
# ...                            ...     ...        ...         ...
# 12300                       Kansas     USA       2011           1
# 12301                   Washington     USA       2017           1
# 12302               Oklahoma State     USA       2014           1
# 12303                       Kansas     USA  Undrafted   Undrafted
# 12304                    Wisconsin     USA  Undrafted   Undrafted
#
#       draft_number  ...   pts   reb  ast  net_rating  oreb_pct  dreb_pct  \
# 0               27  ...   5.7  16.1  3.1        16.1     0.186     0.323
# 1               24  ...   2.3   1.5  0.3        12.3     0.078     0.151
# 2               58  ...   0.8   1.0  0.4        -2.1     0.105     0.102
# 3                9  ...   3.7   2.3  0.6        -8.7     0.060     0.149
# 4               10  ...   2.4   2.4  0.2       -11.2     0.109     0.179
# ...            ...  ...   ...   ...  ...         ...       ...       ...
# 12300           13  ...   7.6   2.6  1.4         4.5     0.059     0.089
# 12301            1  ...  10.8   2.7  5.5        -5.3     0.010     0.116
# 12302            6  ...  12.1   3.8  5.9         9.3     0.018     0.093
# 12303    Undrafted  ...   1.1   1.9  0.6         5.8     0.072     0.108
# 12304    Undrafted  ...   4.0   3.0  0.0       -56.4     0.095     0.125
#
#        usg_pct  ts_pct  ast_pct   season
# 0        0.100   0.479    0.113  1996-97
# 1        0.175   0.430    0.048  1996-97
# 2        0.103   0.376    0.148  1996-97
# 3        0.167   0.399    0.077  1996-97
# 4        0.127   0.611    0.040  1996-97
# ...        ...     ...      ...      ...
# 12300    0.197   0.547    0.116  2021-22
# 12301    0.265   0.517    0.448  2021-22
# 12302    0.179   0.540    0.245  2021-22
# 12303    0.086   0.280    0.069  2021-22
# 12304    0.148   0.505    0.000  2021-22
#
# [12305 rows x 21 columns]

# %% [markdown]
# # Youngest age to play in NBA

# %%
NBA['age'].min()
# Out:
# 18.0

# %% [markdown]
# # Lets see who were the youngest to play in the NBA

# %%
youngest_player = NBA.loc[NBA['age'] == NBA['age'].min()]

youngest_player_name = youngest_player['player_name'].tolist()
youngest_player_age = youngest_player['age'].tolist()

print("The youngers players to play in the NBA are:")
for i in range(len(youngest_player_name)):
    print(youngest_player_name[i], "who is", youngest_player_age[i], "years old.")
# Out:
# The youngers players to play in the NBA are:
# Jermaine O'Neal who is 18.0 years old.
# Kobe Bryant who is 18.0 years old.
# Andrew Bynum who is 18.0 years old.

# %% [markdown]
# # Descriptive stats on all nuemeric categories

# %%
NBA.describe()
# Out:
#                 age        height        weight            gp           pts  \
# count  12305.000000  12305.000000  12305.000000  12305.000000  12305.000000
# mean      27.084518    200.611602    100.369926     51.290532      8.172775
# std        4.335868      9.146321     12.477150     25.095909      5.974957
# min       18.000000    160.020000     60.327736      1.000000      0.000000
# 25%       24.000000    193.040000     90.718400     31.000000      3.600000
# 50%       26.000000    200.660000     99.790240     57.000000      6.700000
# 75%       30.000000    208.280000    108.862080     73.000000     11.500000
# max       44.000000    231.140000    163.293120     85.000000     36.100000
#
#                 reb           ast    net_rating      oreb_pct      dreb_pct  \
# count  12305.000000  12305.000000  12305.000000  12305.000000  12305.000000
# mean       3.559155      1.813986     -2.255733      0.054473      0.141014
# std        2.483550      1.794155     12.673254      0.043599      0.062704
# min        0.000000      0.000000   -250.000000      0.000000      0.000000
# 25%        1.800000      0.600000     -6.400000      0.021000      0.096000
# 50%        3.000000      1.200000     -1.300000      0.041000      0.131000
# 75%        4.700000      2.400000      3.200000      0.084000      0.180000
# max       16.300000     11.700000    300.000000      1.000000      1.000000
#
#             usg_pct        ts_pct       ast_pct
# count  12305.000000  12305.000000  12305.000000
# mean       0.184891      0.511060      0.131358
# std        0.053390      0.101163      0.094483
# min        0.000000      0.000000      0.000000
# 25%        0.149000      0.480000      0.066000
# 50%        0.181000      0.524000      0.103000
# 75%        0.217000      0.561000      0.178000
# max        1.000000      1.500000      1.000000

# %% [markdown]
# # What college produced the most NBA players?

# %%
college_counts = NBA ['college'].value_counts()

# get the name of the most frequent college
most_popular_college = college_counts.index[1]
second_most_popular_college = college_counts.index[2] 
third_most_popular_college = college_counts.index[3] 

print(f"{most_popular_college} produces the most NBA players")
print(f"{second_most_popular_college} produces the 2nd most NBA players")
print(f"{third_most_popular_college} produces the 3rd most NBA players")
# Out:
# Kentucky produces the most NBA players
# Duke produces the 2nd most NBA players
# North Carolina produces the 3rd most NBA players

# %% [markdown]
# # Players that didn't go to college

# %%
NBA[NBA['college'] == 'None']
# Out:
#                  player_name team_abbreviation   age  height      weight  \
# 41                Dino Radja               BOS  30.0  210.82  102.058200
# 78           Jermaine O'Neal               POR  18.0  210.82  102.511792
# 92          Gheorghe Muresan               WAS  26.0  231.14  137.438376
# 134          Arvydas Sabonis               POR  32.0  220.98  132.448864
# 145    Aleksandar Djordjevic               POR  29.0  187.96   89.811216
# ...                      ...               ...   ...     ...         ...
# 12268            Maxi Kleber               DAL  30.0  208.28  108.862080
# 12270            Malik Fitts               BOS  24.0  195.58  104.326160
# 12280            Luka Doncic               DAL  23.0  200.66  104.326160
# 12283           Lou Williams               ATL  35.0  187.96   79.378600
# 12299        Marko Simonovic               CHI  22.0  210.82   99.790240
#
#       college     country draft_year draft_round draft_number  ...   pts  reb  \
# 41       None         USA       1989           2           40  ...  14.0  8.4
# 78       None         USA       1996           1           17  ...   4.1  2.8
# 92       None         USA       1993           2           30  ...  10.6  6.6
# 134      None   Lithuania       1986           1           24  ...  13.4  7.9
# 145      None         USA  Undrafted   Undrafted    Undrafted  ...   3.1  0.6
# ...       ...         ...        ...         ...          ...  ...   ...  ...
# 12268    None     Germany  Undrafted   Undrafted    Undrafted  ...   7.0  5.9
# 12270    None         USA  Undrafted   Undrafted    Undrafted  ...   1.4  1.1
# 12280    None    Slovenia       2018           1            3  ...  28.4  9.1
# 12283    None         USA       2005           2           45  ...   6.3  1.6
# 12299    None  Montenegro       2020           2           44  ...   1.9  1.1
#
#        ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct   season
# 41     1.9        -3.3     0.058     0.217    0.227   0.471    0.092  1996-97
# 78     0.2         1.3     0.099     0.198    0.199   0.494    0.030  1996-97
# 92     0.4         6.9     0.098     0.217    0.185   0.618    0.024  1996-97
# 134    2.1         8.1     0.082     0.282    0.240   0.592    0.136  1996-97
# 145    0.6         4.8     0.021     0.070    0.179   0.687    0.135  1996-97
# ...    ...         ...       ...       ...      ...     ...      ...      ...
# 12268  1.2         3.9     0.047     0.182    0.131   0.537    0.067  2021-22
# 12270  0.3       -16.3     0.033     0.185    0.139   0.553    0.125  2021-22
# 12280  8.7         3.5     0.025     0.230    0.368   0.571    0.458  2021-22
# 12283  1.9         0.8     0.020     0.084    0.215   0.500    0.196  2021-22
# 12299  0.0         1.2     0.122     0.119    0.247   0.428    0.000  2021-22
#
# [1789 rows x 21 columns]

# %% [markdown]
# # Top 10 highest PPG since 1996 season

# %%
# sort the DataFrame by 'pts' column in descending order
Top_10_scorers = NBA.sort_values(by='pts', ascending=False).head(10)

#print player name, pts and season columns
print(Top_10_scorers[['player_name', 'pts', 'season']])
# Out:
#              player_name   pts   season
# 10572       James Harden  36.1  2018-19
# 4342         Kobe Bryant  35.4  2005-06
# 11041       James Harden  34.3  2019-20
# 4124       Allen Iverson  33.0  2005-06
# 2953       Tracy McGrady  32.1  2002-03
# 7928        Kevin Durant  32.0  2013-14
# 11335      Stephen Curry  32.0  2020-21
# 4703         Kobe Bryant  31.6  2006-07
# 9143   Russell Westbrook  31.6  2016-17
# 4323        LeBron James  31.4  2005-06

# %% [markdown]
# # Lets take a look at all of Jayson Tatums stats since he's my favorite player

# %%
NBA[NBA['player_name'] == 'Jayson Tatum']
# Out:
#         player_name team_abbreviation   age  height     weight college  \
# 9756   Jayson Tatum               BOS  20.0   203.2  92.986360    Duke
# 10541  Jayson Tatum               BOS  21.0   203.2  94.347136    Duke
# 11062  Jayson Tatum               BOS  22.0   203.2  95.254320    Duke
# 11269  Jayson Tatum               BOS  23.0   203.2  95.254320    Duke
# 11774  Jayson Tatum               BOS  24.0   203.2  95.254320    Duke
#
#       country draft_year draft_round draft_number  ...   pts  reb  ast  \
# 9756      USA       2017           1            3  ...  13.9  5.0  1.6
# 10541     USA       2017           1            3  ...  15.7  6.0  2.1
# 11062     USA       2017           1            3  ...  23.4  7.0  3.0
# 11269     USA       2017           1            3  ...  26.4  7.4  4.3
# 11774     USA       2017           1            3  ...  26.9  8.0  4.4
#
#        net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct   season
# 9756          6.9     0.021     0.138    0.192   0.586    0.081  2017-18
# 10541         6.8     0.028     0.157    0.218   0.547    0.098  2018-19
# 11062        10.6     0.027     0.165    0.280   0.567    0.143  2019-20
# 11269         3.0     0.021     0.188    0.298   0.576    0.196  2020-21
# 11774        12.1     0.032     0.180    0.313   0.578    0.204  2021-22
#
# [5 rows x 21 columns]

# %% [markdown]
# # Lets see his pts, reb, ast for 2021-2022 season

# %%
player_name = 'Jayson Tatum' # enter player name and season
season = '2021-22'

player_pts = NBA.loc[(NBA['player_name'] == player_name) & (NBA['season'] == season), 'pts']
player_reb = NBA.loc[(NBA['player_name'] == player_name) & (NBA['season'] == season), 'reb']
player_ast = NBA.loc[(NBA['player_name'] == player_name) & (NBA['season'] == season), 'ast']

print(f"{player_name} averaged points per game in {season}: {player_pts.values[0]}")
print(f"{player_name} averaged rebounds per game in {season}: {player_reb.values[0]}")
print(f"{player_name} averaged assits per game in {season}: {player_ast.values[0]}")
# Out:
# Jayson Tatum averaged points per game in 2021-22: 26.9
# Jayson Tatum averaged rebounds per game in 2021-22: 8.0
# Jayson Tatum averaged assits per game in 2021-22: 4.4

# %% [markdown]
# # My favorite player Jayson Tatum Points per game since he was drafted. We will also take a look at Jaylen Browns since they are the best duo in the NBA aka The Jays.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the NBA dataset to only include rows where player_name is JT and JB
jaylen_brown = NBA[NBA['player_name'] == 'Jaylen Brown']
jayson_tatum = NBA[NBA['player_name'] == 'Jayson Tatum']

#Use built in sns fucntion for lineplot
sns.set(style='whitegrid')
sns.lineplot(x='season', y='pts', data=jaylen_brown, color='green', label='Jaylen Brown')
sns.lineplot(x='season', y='pts', data=jayson_tatum, color='lightgreen', label='Jayson Tatum')

# Set the plot title and axes labels
plt.title("The Jays PPG by Season")
plt.xlabel("Season")
plt.ylabel("points per game")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Lets view The Jays assists

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the NBA DataFrame to only include rows where player_name is JT and JB
jaylen_brown = NBA[NBA['player_name'] == 'Jaylen Brown']
jayson_tatum = NBA[NBA['player_name'] == 'Jayson Tatum']

# Use Seaborn's lineplot function to create a line plot for the Jays PPG
sns.set(style='whitegrid')
sns.lineplot(x='season', y='ast', data=jaylen_brown, color='green', label='Jaylen Brown')
sns.lineplot(x='season', y='ast', data=jayson_tatum, color='lightgreen', label='Jayson Tatum')

# Set the plot title and axes labels
plt.title("The Jays Assists by Season")
plt.xlabel("Season")
plt.ylabel("assists per game")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Lets view their rebounds

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the NBA DataFrame to only include rows where player_name is JT and JB
jaylen_brown = NBA[NBA['player_name'] == 'Jaylen Brown']
jayson_tatum = NBA[NBA['player_name'] == 'Jayson Tatum']

# Use Seaborn's lineplot function to create a line plot for the Jays PPG
sns.set(style='whitegrid')
sns.lineplot(x='season', y='reb', data=jaylen_brown, color='green', label='Jaylen Brown')
sns.lineplot(x='season', y='reb', data=jayson_tatum, color='lightgreen', label='Jayson Tatum')


# Set the plot title and axes labels
plt.title("The Jays Rebounds by Season")
plt.xlabel("Season")
plt.ylabel("rebounds per game")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Go Celtice we are winning the Championship this season
